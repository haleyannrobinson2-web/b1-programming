# %%
name = "Haley"
print ("Welcome", name)

score = int(input("your score"))

if score >= 90:
    print ("You're a genius!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 name = "Haley"
# ----> 2 Print ("Welcome", name)
#       4 score = int(input("your score"))
#       6 if score >= 90:
#
# TypeError: 'str' object is not callable
